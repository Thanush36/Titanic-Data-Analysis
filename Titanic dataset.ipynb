# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# # Loading the data into DataFrame

# %%
# Reading the CSV file and loading the data into the DataFrame df_train
df_train = pd.read_csv('train.csv')

# Displaying the DataFrame to view the loaded data
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #  Data Inspection and Exploration

# %% [markdown]
#  ## 1. Displaying basic information

# %%
#Displaying the First Few Rows of the DataFrame

df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
 #Displaying the last Few Rows of the DataFrame
    
df_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Displaying the Shape of the DataFrame df_trai

df_train.shape
# Out:
# (891, 12)

# %%
#Calculating the Total Number of Elements in the DataFrame df_train

df_train.size
# Out:
# 10692

# %%
#Displaying Concise Information about the DataFrame df_train

df_train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Columns: 12 entries, PassengerId to Embarked
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Displaying the Index of the DataFrame df_train

df_train.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#Displaying Column Names in the DataFrame df_train

df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## 2.Identifying Unique_Values

# %%
#Displaying the Number of Unique Values in Each Column

df_train.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ## Displaying unique values for some columns

# %%
df_train['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df_train['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df_train['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df_train['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df_train['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ## 3. Identifying Missing Values in the DataFrame

# %%
df_train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
#  ## Visualization of Missing Values using Heatmap

# %%
# Create a heatmap to visualize missing values in df_train
sns.heatmap(df_train.isnull(), yticklabels=False, cbar=False, cmap='cividis')

# Set the plot title and labels
plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")

# Display the heatmap
plt.show()

# %% [markdown]
#  ## Count of Missing Values in Each Column

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Data Types of Columns in the DataFrame

df_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## 3. Summary_Statistics

# %%
#Summary Statistics with df_train.describe()

df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Descriptive Statistics for the DataFrame df_tra

df_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
#  ## Data Exploration and Visualization

# %% [markdown]
# ## Passenger Survival Count

# %%
# Creating the countplot
sns.countplot(x='Survived', data=df_train)

# Adding title and axis labels
plt.title('Passenger Survival Count')
plt.xlabel('Survival (0: Not Survived, 1: Survived)')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Question 1: What is the overall survival rate of passengers aboard the Titanic?

# %%
# Calculate the overall survival rate
overall_survival_rate = df_train['Survived'].mean()

# Print the result
print("Overall Survival Rate:", overall_survival_rate)
# Out:
# Overall Survival Rate: 0.3838383838383838

# %% [markdown]
# ## Question 2: Is there any significant difference in the survival rates between male and female passengers?

# %%
# Create a countplot to visualize survival count by gender
sns.countplot(x='Survived', hue='Sex', data=df_train)

# Add title and axis labels
plt.title('Survival Count by Gender')
plt.xlabel('Survival (0: Not Survived, 1: Survived)')
plt.ylabel('Count')

# Display the plot
plt.show()

# %% [markdown]
# ## calculating the survival rate for each group

# %%
# Grouping data by 'Sex' and calculating the mean of 'Survived' column for each gender

survival_rate_by_gender = df_train.groupby('Sex')['Survived'].mean()


# Displaying the survival rate by gender

print("Survival Rate by Gender:")
print(survival_rate_by_gender)
# Out:
# Survival Rate by Gender:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# ## Calculating the percentage of survival for female and male passengers

# %%
total_female_passengers = df_train['Sex'].value_counts()['female']
total_male_passengers = df_train['Sex'].value_counts()['male']

# Calculating the number of female and male survivors

female_survivors = df_train[df_train['Sex'] == 'female']['Survived'].sum()
male_survivors = df_train[df_train['Sex'] == 'male']['Survived'].sum()


# Calculating the percentage of survival for female and male passengers

percentage_female_survival = (female_survivors / total_female_passengers) * 100
percentage_male_survival = (male_survivors / total_male_passengers) * 100

# Displaying the results

print("Percentage of Survival for Females:", percentage_female_survival)
print("Percentage of Survival for Males:", percentage_male_survival)
# Out:
# Percentage of Survival for Females: 74.20382165605095
# Percentage of Survival for Males: 18.890814558058924

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = 'Passenger_class', hue = 'Survived',data = df_train)
plt.title('Survival by Passenger_class')
plt.xlabel('Passenger_class')
plt.ylabel('count')
plt.legend(title='Survived',labels = ['Not Survived','Survived'])
plt.show()

# %% [markdown]
# # Data Formatting

# %% [markdown]
# ## Renaming the columns for better understanding

# %%
df_train.rename(columns={'Pclass':'Passenger_class','Sex':'Gender','SibSp':'Siblings_Spouse_Aboard','Parch':'Parents_Children_Aboard','Embarked':'Port_of_Embarkation'}, inplace=True)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Passenger_class', 'Name', 'Gender', 'Age',
#        'Siblings_Spouse_Aboard', 'Parents_Children_Aboard', 'Ticket', 'Fare',
#        'Cabin', 'Port_of_Embarkation'],
#       dtype='object')

# %%
df_train
# Out:
#      PassengerId  Survived  Passenger_class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   Name  Gender   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## step-1. Handling missing Data

# %% [markdown]
# ### Identify missing values

# %%
missing_values = df_train.isnull().sum()
print('Missing Values: ')
print(missing_values)
# Out:
# Missing Values:
# PassengerId                  0
# Survived                     0
# Passenger_class              0
# Name                         0
# Gender                       0
# Age                        177
# Siblings_Spouse_Aboard       0
# Parents_Children_Aboard      0
# Ticket                       0
# Fare                         0
# Cabin                      687
# Port_of_Embarkation          2
# dtype: int64

# %% [markdown]
# ### Handling missing 'Age' value with mean imputation

# %%
mean_age = df_train['Age'].mean()
df_train['Age'].fillna(mean_age,inplace=True)

# %% [markdown]
# ### Handling missing 'Cabin' value by filling with a placeholder

# %%
df_train['Cabin'].fillna('Unknown',inplace=True)

# %% [markdown]
# ### Handling missing 'Port_of_embarkation' value with mode

# %%
mode_Port_of_Embarkation=df_train['Port_of_Embarkation'].mode().iloc[0]
df_train['Port_of_Embarkation'].fillna('mode_Port_of_Embarkation',inplace=True)

# %%
df_train.isnull().sum()
# Out:
# PassengerId                0
# Survived                   0
# Passenger_class            0
# Name                       0
# Gender                     0
# Age                        0
# Siblings_Spouse_Aboard     0
# Parents_Children_Aboard    0
# Ticket                     0
# Fare                       0
# Cabin                      0
# Port_of_Embarkation        0
# dtype: int64

# %%
# Plot Port_of_Embarkation Distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='Port_of_Embarkation',hue = 'Survived', data=df_train, palette='muted')
plt.title('Port of Embarkation Distribution')
plt.xlabel('Port of Embarkation')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## step-2 : Data Type conversions

# %% [markdown]
# ### Convert survived , parent_children_aboard , siblings_spouse_aboard , passenger_class columns into categories

# %%
df_train['Survived'] = df_train['Survived'].astype('category')

df_train['Parents_Children_Aboard'] = df_train['Parents_Children_Aboard'].astype('category')

df_train['Siblings_Spouse_Aboard'] = df_train['Siblings_Spouse_Aboard'].astype('category')

df_train['Passenger_class'] = df_train['Passenger_class'].astype('category')

# %%
df_train.dtypes
# Out:
# PassengerId                   int64
# Survived                   category
# Passenger_class            category
# Name                         object
# Gender                       object
# Age                         float64
# Siblings_Spouse_Aboard     category
# Parents_Children_Aboard    category
# Ticket                       object
# Fare                        float64
# Cabin                        object
# Port_of_Embarkation          object
# dtype: object

# %% [markdown]
# ## step-3 : Removing Duplicates

# %%
df_train.drop_duplicates(inplace=True)

# %% [markdown]
# # Identifying outliers

# %%
# Selecting numerical columns for the box plot
numerical_columns = df_train.select_dtypes(include=['int64', 'float64']).columns

# Creating a box plot to visualize outliers in numerical columns
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_train[numerical_columns])
plt.xticks(rotation=45)
plt.title("Box Plot: Outliers Detection")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ## Removing Outliers in 'Age' and 'Fare' columns

# %%
# Function to remove outliers based on IQR method
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Removing outliers from 'Age' and 'Fare' columns
df_train_no_outliers = remove_outliers(df_train, 'Age')
df_train_no_outliers = remove_outliers(df_train_no_outliers, 'Fare')

# Displaying the shape of the DataFrame after removing outliers
print("Shape of DataFrame after removing outliers:", df_train_no_outliers.shape)
# Out:
# Shape of DataFrame after removing outliers: (718, 12)

# %% [markdown]
# ## Cleaned Data after Removing Outliers and Missing Values

# %%
 #Selecting numerical columns for the box plot
numerical_columns = df_train.select_dtypes(include=['int64', 'float64']).columns

# Creating a box plot to visualize outliers in numerical columns
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_train_no_outliers[numerical_columns])
plt.xticks(rotation=45)
plt.title("Box Plot: Outliers Detection")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ## What is the relationship between the age and fare paid by passengers on the Titanic?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_train_no_outliers, x='Age', y='Fare', marker='o', color='b')
plt.title('Scatter Plot (Outliers Removed): Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
## Convert categorical columns back to numeric format
df_train_no_outliers['Survived'] = df_train['Survived'].astype(int)
df_train_no_outliers['Parents_Children_Aboard'] = df_train['Parents_Children_Aboard'].astype(int)
df_train_no_outliers['Siblings_Spouse_Aboard'] = df_train['Siblings_Spouse_Aboard'].astype(int)
df_train_no_outliers['Passenger_class'] = df_train['Passenger_class'].astype(int)

# Calculate the mean of 'Survived'
mean_survived = df_train_no_outliers['Survived'].mean()
print("Mean of 'Survived':", mean_survived)
# Out:
# Mean of 'Survived': 0.3342618384401114

# %% [markdown]
# ## survival by Passenger_class

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = 'Passenger_class', hue = 'Survived',data = df_train_no_outliers)
plt.title('Survival by Passenger_class')
plt.xlabel('Passenger_class')
plt.ylabel('count')
plt.legend(title='Survived',labels = ['Not Survived','Survived'])
plt.show()

# %% [markdown]
# ## Survival rate by Passenger_class

# %%
# Create a bar plot for survival rate by passenger class
survival_rate_by_class = df_train_no_outliers.groupby('Passenger_class')['Survived'].mean()

plt.figure(figsize=(8, 6))
sns.barplot(x=survival_rate_by_class.index, y=survival_rate_by_class.values, palette='viridis')
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')

# Adding legend
for index, value in enumerate(survival_rate_by_class.values):
    plt.text(index, value, f"{value:.2f}", ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# ## Survival by Gender

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = 'Gender', hue = 'Survived',data = df_train_no_outliers)
plt.title('Survival by Gender')
plt.xlabel('Gender')
plt.ylabel('count')
plt.legend(title='Survived',labels = ['Not Survived','Survived'])
plt.show()

# %% [markdown]
# ## survival rate by Gender

# %%
# Calculate survival rate by gender
survival_rate_by_gender = df_train_no_outliers.groupby('Gender')['Survived'].mean()

# Visualize survival rate by gender
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_by_gender.index, y=survival_rate_by_gender.values, palette='muted')
plt.title('Survival Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')

# Adding labels on top of the bars
for index, value in enumerate(df_train_no_outliers.groupby('Gender')['Survived'].mean()):
    plt.text(index, value, f"{value:.2f}", ha='left', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# ## Age distribution

# %%
# Plot Age Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df_train_no_outliers['Age'], kde=True, color='blue', bins=20)
plt.title('Age Distribution after Removing Outliers')
plt.xlabel('Age')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ## Fare Distribution

# %%
# Plot Fare Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df_train_no_outliers['Fare'], kde=True, color='green', bins=30)
plt.title('Fare Distribution after Removing Outliers')
plt.xlabel('Fare')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ## Relation between Fare and Passenger_class

# %%
# Create a violin plot for fare by passenger class
plt.figure(figsize=(8, 6))
sns.violinplot(x='Passenger_class', y='Fare', data=df_train_no_outliers, palette='bright')
plt.title('Relationship between Passenger Class and Fare (after Removing Outliers)')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')

plt.show()

# %% [markdown]
# ## Relation between Survival and Family size

# %%
# Calculate the family size by adding 'Siblings_Spouse_Aboard' and 'Parents_Children_Aboard'
df_train_no_outliers['Family_Size'] = df_train_no_outliers['Siblings_Spouse_Aboard'] + df_train_no_outliers['Parents_Children_Aboard']

# Visualize count of passengers for each family size using a countplot
plt.figure(figsize=(10, 6))
sns.countplot(x='Family_Size',hue='Survived' ,data=df_train_no_outliers, palette='bright')
plt.title('Passenger Count by Family Size (after Removing Outliers)')
plt.xlabel('Family Size')
plt.ylabel('Passenger Count')

plt.show()

# %% [markdown]
# ## Survival rate by Family size

# %%
# Calculate the family size by adding 'Siblings_Spouse_Aboard' and 'Parents_Children_Aboard'
df_train_no_outliers['Family_Size'] = df_train_no_outliers['Siblings_Spouse_Aboard'] + df_train_no_outliers['Parents_Children_Aboard']

# Calculate the survival rate by family size
survival_rate_by_family_size = df_train_no_outliers.groupby('Family_Size')['Survived'].mean()

# Visualize survival rate by family size using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=survival_rate_by_family_size.index, y=survival_rate_by_family_size.values, palette='bright')
plt.title('Survival Rate by Family Size (after Removing Outliers)')
plt.xlabel('Family Size')
plt.ylabel('Survival Rate')

plt.show()

# %% [markdown]
# ## Relation between survival and port of embarkation

# %%
# Create a countplot for survival based on port of embarkation
plt.figure(figsize=(8, 6))
sns.countplot(x='Port_of_Embarkation', hue='Survived', data=df_train_no_outliers, palette='bright')
plt.title('Survival Count by Port of Embarkation (after Removing Outliers)')
plt.xlabel('Port of Embarkation')
plt.ylabel('Count')

# Add legend to the plot
plt.legend(['Not Survived', 'Survived'])

plt.show()

# %% [markdown]
# ## Survival rate and Port of Embarkation

# %%
# Calculate mean survival rate by port of embarkation
survival_rate_by_embarkation = df_train_no_outliers.groupby('Port_of_Embarkation')['Survived'].mean()

# Visualize survival rate by port of embarkation using a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=survival_rate_by_embarkation.index, y=survival_rate_by_embarkation.values, palette='bright')
plt.title('Survival Rate by Port of Embarkation (after Removing Outliers)')
plt.xlabel('Port of Embarkation')
plt.ylabel('Survival Rate')

plt.show()

# %% [markdown]
# ## Impact of Age group and Gender on Survival

# %%
# Bin the 'Age' variable into different age groups
age_bins = [0, 18, 30, 50, 100]
age_labels = ['Child', 'Young Adult', 'Adult', 'Elderly']
df_train_no_outliers['Age_Group'] = pd.cut(df_train_no_outliers['Age'], bins=age_bins, labels=age_labels, right=False)

# Create a bar plot for survival based on age group and gender with a 'bright' palette
plt.figure(figsize=(8, 6))
sns.barplot(x='Age_Group', y='Survived', hue='Gender', data=df_train_no_outliers, palette='bright')
plt.title('Impact of Age Group and Gender on Survival (after Removing Outliers)')
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.legend(title='Gender', loc='upper left', labels=['Female', 'Male'])

plt.show()

# %%
df_train_no_outliers.dtypes
# Out:
# PassengerId                   int64
# Survived                      int32
# Passenger_class               int32
# Name                         object
# Gender                       object
# Age                         float64
# Siblings_Spouse_Aboard        int32
# Parents_Children_Aboard       int32
# Ticket                       object
# Fare                        float64
# Cabin                        object
# Port_of_Embarkation          object
# Family_Size                   int32
# Age_Group                  category
# dtype: object

# %%
df_train_no_outliers['Survived'] = df_train['Survived'].astype('category')

df_train_no_outliers['Parents_Children_Aboard'] = df_train['Parents_Children_Aboard'].astype('category')

df_train_no_outliers['Siblings_Spouse_Aboard'] = df_train['Siblings_Spouse_Aboard'].astype('category')

df_train_no_outliers['Passenger_class'] = df_train['Passenger_class'].astype('category')

# %%
df_train_no_outliers.dtypes
# Out:
# PassengerId                   int64
# Survived                   category
# Passenger_class            category
# Name                         object
# Gender                       object
# Age                         float64
# Siblings_Spouse_Aboard     category
# Parents_Children_Aboard    category
# Ticket                       object
# Fare                        float64
# Cabin                        object
# Port_of_Embarkation          object
# Family_Size                   int32
# Age_Group                  category
# dtype: object

# %% [markdown]
# ## Removing Irrelavent columns

# %%
# List of columns to remove
columns_to_remove = ['PassengerId', 'Name', 'Ticket', 'Cabin']

# Remove the columns from the DataFrame
df_train_no_outliers = df_train_no_outliers.drop(columns=columns_to_remove, axis=1)

# Display the modified DataFrame
df_train_no_outliers.head()
# Out:
#   Survived Passenger_class  Gender        Age Siblings_Spouse_Aboard  \
# 0        0               3    male  22.000000                      1
# 2        1               3  female  26.000000                      0
# 3        1               1  female  35.000000                      1
# 4        0               3    male  35.000000                      0
# 5        0               3    male  29.699118                      0
#
#   Parents_Children_Aboard     Fare Port_of_Embarkation  Family_Size  \
# 0                       0   7.2500                   S            1
# 2                       0   7.9250                   S            0
# 3                       0  53.1000                   S            1
# 4                       0   8.0500                   S            0
# 5                       0   8.4583                   Q            0
#
#      Age_Group
# 0  Young Adult
# 2  Young Adult
# 3        Adult
# 4        Adult
# 5  Young Adult

# %%
df_train_no_outliers.dtypes
# Out:
# Survived                   category
# Passenger_class            category
# Gender                       object
# Age                         float64
# Siblings_Spouse_Aboard     category
# Parents_Children_Aboard    category
# Fare                        float64
# Port_of_Embarkation          object
# Family_Size                   int32
# Age_Group                  category
# dtype: object
